# %% [markdown]
# # 16. Decorators in Python
#
#  * __Decorator provides a simple syntax for calling higher-order functions.__
#  * __By definition, a decorator is a function that takes other funcitons and extends their behavious without modifying them.__
#  * __Decorators can be extremely useful as they allow the extension of an exising function, without any modification to the original function source code.__
#  * __In fact, there are two types of decorator in Python: class decorator and function decorator.__
#  * __In application, decorators are mainly used in creating a middle layer in the backend, which perform tasks like token authentication, image compression, validation, and many more.__

# %%
# Client <-----------------------> Server

# %%
import decorator

# %%
def myText(text):
    return "Congratulations! "+ text
myText("Linesh")
# Out:
# 'Congratulations! Linesh'

# %%
def text2():
    name = input("Enter your name here: ")
    return "Congratulations! "+ name

text2()
# Out:
# Enter your name here:  linesh
# 'Congratulations! linesh'

# %%
# find the square of the number 

def sqr():
    val = int(input("Enter any value: "))
    sqrNum = val**2
    return f"Square of the number {val} is: {sqrNum}"
sqr()
# Out:
# Enter any value:  10
# 'Square of the number 10 is: 100'

# %%
# nested function: function inside function 

def myText():
    print("Python is a programming language.")
    def newText():
        print("Hello Linesh")
    def secondText():
        print("Congratulations! Linesh")
    newText()
    secondText()

myText()
# Out:
# Python is a programming language.
# Hello Linesh
# Congratulations! Linesh

# %%
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
def multi(x): # multi(3)
    return x*math.pi # 3.141592653589793
multi(10)
# Out:
# 31.41592653589793

# %%
def div(y):
    return y/math.pi

div(13)
# Out:
# 4.138028520389279

# %%
def operator11(func,x1): # func: function # x1 is variable which you can pass numerical value
    num = func(x1)  # multi(3)
    return num 

operator11(multi,3)
# Out:
# 9.42477796076938

# %%
# multi(50)

# %%
def operator11(a,x1): # func: function # x1 is variable which you can pass numerical value
    print("----------------",a,x1)
    num = a(x1)  # multi(3)
    return num 

operator11(multi,3)
# Out:
# ---------------- <function multi at 0x00000215BAEE2700> 3
# 9.42477796076938

# %%
# wirte a program to calulate the sum of two numbers.


def sumTwo():
    num1 = int(input("Enter first Number: "))
    num2 = int(input("Enter second Number: "))
    value = num1+num2
    return f"The sum of two numbers {num1} and {num2} is:{value}"

# %%
def operator11(func): # func: function # x1 is variable which you can pass numerical value
    num = func()  # multi(3)
    return num 

operator11(sumTwo)
# Out:
# Enter first Number:  45
# Enter second Number:  96
# 'The sum of two numbers 45 and 96 is:141'

# %%
def decoratedCase(val): # linesh
    def text():
        function= val()  # linesh()
        textUpper = function.upper() # LINESH
        return textUpper
    return text

def text1():
    name = "linesh"
    return name
text1()
# Out:
# 'linesh'

# %%
decoratedCase(text1)
# Out:
# <function __main__.decoratedCase.<locals>.text()>

# %%
@decoratedCase
def text1():
    name = "linesh"
    return name
text1()
# Out:
# 'LINESH'

# %%
@decoratedCase
def text2():
    userVal = input("Enter any Value: ")
    return userVal

text2()
# Out:
# Enter any Value:  Trade‑in values will vary based on the condition, year, and configuration of your eligible trade‑in device. Not all devices are eligible for credit. You must be at least the age of majority to be eligible to trade in for credit or for an Apple Gift Card. Trade‑in value may be applied toward qualifying new device purchase, or added to an Apple Gift Card. Actual value awarded is based on receipt of a qualifying device matching the description provided when estimate was made. Sales tax may be assessed on full value of a new device purchase. In‑store trade‑in requires presentation of a valid photo ID (local law may require saving this information). Offer may not be available in all stores and may vary between in‑store and online trade‑in. Some stores may have additional requirements. Apple or its trade‑in partners reserve the right to refuse, cancel, or limit quantity of any trade‑in transaction for any reason. More details are available from Apple’s trade-in partner fo
# ...
