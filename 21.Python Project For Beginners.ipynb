# %% [markdown]
# # Project Name
#
# ### 1. Student Management System
#  * __Student Management system__
#    * __manages students details like:__
#    * __name, roll number, marks and allows add, view, update, and delete operations.__
# ### 2. Library Management System
#  * __To manage library: Add new books, view all books, Issue all books, Return a book.__
# ### 3. Bank Management System
#  * __To Manage Bank: Create Account, Deposite Money, Withdraw Money, Check Balance, Display Account Details.__
# ### 4. Employee Management System
#  * __To Manage Employee records: Add Employee, View all Employee, Search Employee, update Employee, Delete Employee.__
# ### 5. ATM Management System
#  * __To Manage Bank: Create Account, Deposite Money, Withdraw Money, Check Balance, Display Account Details.__
# ### 6. Contact Book Application
#  * __To manage Contact Details: Add new Contact, View all contact, search contact, Update Contact, Delete contact.__
# ### 7. Online Quiz system
#  * __To conduct Online Quiz__
#    * __Display Questions__
#    * __Accept user answer.__
#    * __Calculate Score.__
#    * __Show Final Result.__
# ### 8. Movie Ticket Booking System(Basic)
#  * __To simulate a movie ticket booking system.__
#    * __View available movie__
#    * __Book tickets.__
#    * __calculate total price.__
#    * __show booking details.__
# ### 9. Inventory Management System
#  * __To manage produce stock.__
#     * __Add new product__
#     * __view all products.__
#     * __update product quantity.__
#     * __delete product__
#     * __Check low stock.__
# ### 10. Hotel Booking System
#  * __To Manage hotel room bookings system.__
#    * __View available rooms__
#    * __Book a room.__
#    * __Check-Out(Vacate Room)__
#    * __Viedw booking details.__
# ### 11. Online Shopping Cart System
#  * __To simulate an online shopping__
#    * __View products__
#    * __Add product to cart__
#    * __Remove product from cart__
#    * __View cart__
#    * __Calcute total bill__
# ### 12. Vehicle Rental System
#  * __To manage vehicle Rental__
#    * __View available vehicles__
#    * __Rent a vehicle__
#    * __calculate rental cost__
# ### 13. Restaurent Ordering System
#  * __To manage food ordering in a restaurent.__
#    * __view menu__
#    * __Place order__
#    * __Generate bill__
#    * __Exit system__
#
# ### 14. Task/To-Do List Manager.
#  * __To manage daily tasks__
#    * __Add new task__
#    * __view all tasks__
#    * __Mark tesk as completed__
#    * __Delete task__
# ### 15. School Fee Management System
#  * __To manage student fee records__
#    * __Add student__
#    * __View student details__
#    * __Pay fees__
#    * __Check pending fees__
# ### 16. College Management System
#  * __To manage basic college records__
#    * __Add Students__
#    * __Add courses__
#    * __Enroll students in courses__
#    * __View student details__
# ### 17. Hospital management System
#  * __To manage hospital records__
#    * __Add patients__
#    * __Add doctors__
#    * __Assign doctors to patients__
#    * __View patient details.__
# ### 18. Payroll Management System
#  * __To calculate and manage emplyee salaries__
#     * __Add employees__
#     * __calcualte salary__
#     * __view payroll details__
#
# ### 19. E-Library Project
#  * __To manage digital library records__
#     * __Add books__
#     * __View available books__
#     * __Issue books to users__
#     * __Return Books__
#
# ### 20. Job Protal(console Based)
#  * __To Manage job positings and job seekers__
#    * __Add job seekers__
#    * __Add job openings__
#    * __Apply for jobs__
#    * __view applicants__
